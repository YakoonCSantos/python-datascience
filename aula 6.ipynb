# %%
import pandas as pd
#https://www.kaggle.com/ashirwadsangwan/imdb-dataset
# TSV (CSV/TXT) Enconding Latin1 ou Utf-8

# %%
#pd.read_csv('',sep = '\t', enconding) padrão para leitura no pandas
#definindo os caminhos dos arquivos
names = pd.read_csv('C:/Users/fic/Documents/IMDb Dataset/name.basics.tsv/name.basics.tsv', sep = "\t")
titles = pd.read_csv('C:/Users/fic/Documents/IMDb Dataset/title.akas.tsv/title.akas.tsv', sep = "\t")
titles_basic = pd.read_csv('C:/Users/fic/Documents/IMDb Dataset/title.basics.tsv/title.basics.tsv', sep = "\t")
#titles_principal = pd.read_csv('C:/Users/fic/Documents/IMDb Datasettitle.principals.tsv/title.principals.tsv', sep = "\t")
titles_rating = pd.read_csv('C:/Users/fic/Documents/IMDb Dataset/title.ratings.tsv/title.ratings.tsv', sep = "\t")
# Out:
# C:\Users\fic\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\fic\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
names.head(50) #Retorne as primeiras n linhas. Esta função retorna as primeiras n linhas para o objeto com base na posição. É útil para testar rapidamente se o seu objeto possui o tipo certo de dados.
# Out:
#        nconst          primaryName birthYear deathYear  \
# 0   nm0000001         Fred Astaire      1899      1987
# 1   nm0000002        Lauren Bacall      1924      2014
# 2   nm0000003      Brigitte Bardot      1934        \N
# 3   nm0000004         John Belushi      1949      1982
# 4   nm0000005       Ingmar Bergman      1918      2007
# 5   nm0000006       Ingrid Bergman      1915      1982
# 6   nm0000007      Humphrey Bogart      1899      1957
# 7   nm0000008        Marlon Brando      1924      2004
# 8   nm0000009       Richard Burton      1925      1984
# 9   nm0000010         James Cagney      1899      1986
# 10  nm0000011          Gary Cooper      1901      1961
# 11  nm0000012          Bette Davis      1908      1989
# 12  nm0000013            Doris Day      1922      2019
# 13  nm0000014  Olivia de Havilland      1916        \N
# 14  nm0000015           James Dean      1931      1955
# 15  nm0000016      Georges Delerue      1925      1992
# ...

# %%
names.tail(50) # Retorne as últimas n linhas.  Esta função retorna as últimas n linhas do objeto com base na posição. É útil para verificar dados rapidamente, por exemplo, após classificar ou anexar linhas.
# Out:
#             nconst                primaryName birthYear deathYear  \
# 9706872  nm9993668            Harry Traksmann        \N        \N
# 9706873  nm9993669            Valeria Malinen        \N        \N
# 9706874  nm9993670                 Ken Hallen        \N        \N
# 9706875  nm9993671             Marko Lampinen        \N        \N
# 9706876  nm9993672           Simone Hulsemann        \N        \N
# 9706877  nm9993673             Petra Jarosova        \N        \N
# 9706878  nm9993674                 Kerli Raag        \N        \N
# 9706879  nm9993675             Ebrahim Alqazi        \N        \N
# 9706880  nm9993676     Bonnie & The Treasures        \N        \N
# 9706881  nm9993677             Earldine Smith        \N        \N
# 9706882  nm9993678         Nisha Rivas Freeze        \N        \N
# 9706883  nm9993679                  Art Jones        \N        \N
# 9706884  nm9993680  Christopher-Lawson Palmer        \N        \N
# ...

# %%
names.describe()
# Out:
#            nconst  primaryName birthYear deathYear primaryProfession  \
# count     9706922      9706922   9706922   9706922           7775897
# unique    9706922      7618021       481       422             19674
# top     nm2119953  David Smith        \N        \N             actor
# freq            1          310   9215641   9534917           1772491
#
#        knownForTitles
# count         9706922
# unique        4036203
# top                \N
# freq          1689596

# %%
titles_basic.head(50)
# Out:
#        tconst titleType                                   primaryTitle  \
# 0   tt0000001     short                                     Carmencita
# 1   tt0000002     short                         Le clown et ses chiens
# 2   tt0000003     short                                 Pauvre Pierrot
# 3   tt0000004     short                                    Un bon bock
# 4   tt0000005     short                               Blacksmith Scene
# 5   tt0000006     short                              Chinese Opium Den
# 6   tt0000007     short    Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short         Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     movie                                     Miss Jerry
# 9   tt0000010     short                            Exiting the Factory
# 10  tt0000011     short                        Akrobatisches Potpourri
# 11  tt0000012     short                         The Arrival of a Train
# ...

# %%
titles_basic.tail(50)
# Out:
#             tconst  titleType  \
# 6321252  tt9916754      movie
# 6321253  tt9916756      short
# 6321254  tt9916758  tvEpisode
# 6321255  tt9916760  tvEpisode
# 6321256  tt9916762  tvEpisode
# 6321257  tt9916764      short
# 6321258  tt9916766  tvEpisode
# 6321259  tt9916768  tvEpisode
# 6321260  tt9916770  tvEpisode
# 6321261  tt9916774  tvEpisode
# 6321262  tt9916776  tvEpisode
# 6321263  tt9916778  tvEpisode
# 6321264  tt9916780  tvEpisode
# 6321265  tt9916782  tvEpisode
# 6321266  tt9916784  tvEpisode
# 6321267  tt9916786  tvEpisode
# 6321268  tt9916788  tvEpisode
# 6321269  tt9916790  tvEpisode
# 6321270  tt9916792  tvEpisode
# 6321271  tt9916794  tvEpisode
# 6321272  tt9916796  tvEpisode
# 6321273  tt9916798  tvEpisode
# 6321274  tt9916800  tvEpisode
# 6321275  tt9916802  tvEpisode
# 6321276  tt9916804  tvEpisode
# 6321277  tt9916806  tvEpisode
# 6321278  tt9916808  tvEpisode
# 6321279  tt9916810  tvEpisode
# 6321280  tt9916812  tvEpisode
# 6321281  tt9916814  tvEpisode
# ...

# %%
titles_basic.describe()
# Out:
#             isAdult
# count  6.321302e+06
# mean   3.309176e-02
# std    2.537068e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    2.019000e+03

# %%
titles_basic['titleType'].unique() # saber quais são os dados unicos que tem na tabela Basic Retorne valores exclusivos no índice. Os itens únicos são retornados em ordem de aparência, isso NÃO classifica.
# Out:
# array(['short', 'movie', 'tvMovie', 'tvSeries', 'tvEpisode', 'tvShort',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
titles_rating.head(5)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1550
# 1  tt0000002            6.1       186
# 2  tt0000003            6.5      1207
# 3  tt0000004            6.2       113
# 4  tt0000005            6.1      1934

# %%
titles_sliced = titles_basic.iloc[:,[0,1,2,8]]  #minimizar a tabela para uma visualização curta, com
titles_sliced.head(5)
# Out:
#       tconst titleType            primaryTitle                    genres
# 0  tt0000001     short              Carmencita         Documentary,Short
# 1  tt0000002     short  Le clown et ses chiens           Animation,Short
# 2  tt0000003     short          Pauvre Pierrot  Animation,Comedy,Romance
# 3  tt0000004     short             Un bon bock           Animation,Short
# 4  tt0000005     short        Blacksmith Scene              Comedy,Short

# %%
titles_sliced.columns = ['tconst','tipo', 'titulo', 'genero']  ###renomear o nome das colunas com a função Columns 
titles_sliced.head(5)
# Out:
#       tconst   tipo                  titulo                    genero
# 0  tt0000001  short              Carmencita         Documentary,Short
# 1  tt0000002  short  Le clown et ses chiens           Animation,Short
# 2  tt0000003  short          Pauvre Pierrot  Animation,Comedy,Romance
# 3  tt0000004  short             Un bon bock           Animation,Short
# 4  tt0000005  short        Blacksmith Scene              Comedy,Short

# %%
titles_rating_merge = titles_rating.merge(titles_sliced, left_on = 'tconst', right_on = 'tconst') # fazendo a junção das tabelas com Merge, utilizando a coluna TCONST como chave primaria   
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html?highlight=merge#pandas.merge
titles_rating_merge.head(5)
# Out:
#       tconst  averageRating  numVotes   tipo                  titulo  \
# 0  tt0000001            5.6      1550  short              Carmencita
# 1  tt0000002            6.1       186  short  Le clown et ses chiens
# 2  tt0000003            6.5      1207  short          Pauvre Pierrot
# 3  tt0000004            6.2       113  short             Un bon bock
# 4  tt0000005            6.1      1934  short        Blacksmith Scene
#
#                      genero
# 0         Documentary,Short
# 1           Animation,Short
# 2  Animation,Comedy,Romance
# 3           Animation,Short
# 4              Comedy,Short

# %%
titles_rating_merge.sort_values(by =['numVotes'], ascending=False).head(100) # faça a ordenação da coluna NUMVOTES do maior para o menor e imprima as 30 primeiras linhas
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html?highlight=sort_values
# Out:
#            tconst  averageRating  numVotes      tipo  \
# 80579   tt0111161            9.3   2159745     movie
# 241008  tt0468569            9.0   2134602     movie
# 515622  tt1375666            8.8   1892958     movie
# 96689   tt0137523            8.8   1725444     movie
# 80363   tt0110912            8.9   1695159     movie
# 79501   tt0109830            8.8   1662609     movie
# 413358  tt0944947            9.4   1606096  tvSeries
# 94660   tt0133093            8.7   1554345     movie
# 88334   tt0120737            8.8   1548920     movie
# 111186  tt0167260            8.9   1533632     movie
# 44727   tt0068646            9.2   1482225     movie
# 509867  tt1345836            8.4   1421506     movie
# 111187  tt0167261            8.7   1387208     movie
# 378552  tt0816692            8.6   1348184     movie
# 83129   tt0114369            8.6   1327441     movie
# 403836  tt0903747            9.5   1280143  tvSeries
# 596786  tt1853728            8.4   1249336     movie
# ...

# %%
top = titles_rating_merge[(titles_rating_merge['numVotes'] > 50000) & (titles_rating_merge['tipo'] == 'movie')].sort_values(by =['averageRating'], ascending=False).head(50)
top
# Out:
#            tconst  averageRating  numVotes   tipo  \
# 80579   tt0111161            9.3   2159745  movie
# 44727   tt0068646            9.2   1482225  movie
# 47237   tt0071562            9.0   1032110  movie
# 854299  tt5813916            9.0    101817  movie
# 241008  tt0468569            9.0   2134602  movie
# 78033   tt0108052            8.9   1120297  movie
# 80363   tt0110912            8.9   1695159  movie
# 28825   tt0050083            8.9    617607  movie
# 111186  tt0167260            8.9   1533632  movie
# 96689   tt0137523            8.8   1725444  movie
# 79501   tt0109830            8.8   1662609  movie
# 88334   tt0120737            8.8   1548920  movie
# 515622  tt1375666            8.8   1892958  movie
# 37522   tt0060196            8.8    640941  movie
# 921072  tt7286456            8.8    466912  movie
# 94660   tt0133093            8.7   1554345  movie
# 48858   tt0073486            8.7    852798  movie
# 71146   tt0099685            8.7    933687  movie
# ...

# %%
top1 = titles_rating_merge[(titles_rating_merge['tipo'] == 'movie')].sort_values(by =['numVotes'], ascending=False).head(50)
top1
# Out:
#            tconst  averageRating  numVotes   tipo  \
# 80579   tt0111161            9.3   2159745  movie
# 241008  tt0468569            9.0   2134602  movie
# 515622  tt1375666            8.8   1892958  movie
# 96689   tt0137523            8.8   1725444  movie
# 80363   tt0110912            8.9   1695159  movie
# 79501   tt0109830            8.8   1662609  movie
# 94660   tt0133093            8.7   1554345  movie
# 88334   tt0120737            8.8   1548920  movie
# 111186  tt0167260            8.9   1533632  movie
# 44727   tt0068646            9.2   1482225  movie
# 509867  tt1345836            8.4   1421506  movie
# 111187  tt0167261            8.7   1387208  movie
# 378552  tt0816692            8.6   1348184  movie
# 83129   tt0114369            8.6   1327441  movie
# 596786  tt1853728            8.4   1249336  movie
# 113555  tt0172495            8.5   1246819  movie
# 201998  tt0372784            8.2   1225060  movie
# 388847  tt0848228            8.0   1206913  movie
# ...

# %%
top2 = top.groupby(['tipo', 'genero']).agg({'numVotes':'sum'}) #contrução da tabela dinamica , pivotagem
top2
# Out:
#                                    numVotes
# tipo  genero
# movie Action,Adventure,Drama        1539060
#       Action,Adventure,Fantasy      2226018
#       Action,Adventure,Sci-Fi       1892958
#       Action,Crime,Drama            3089937
#       Action,Drama,War               101817
#       Action,Sci-Fi                 2489181
#       Adventure,Animation,Drama      871796
#       Adventure,Animation,Family     577038
#       Adventure,Comedy,Sci-Fi        965539
#       Adventure,Drama,Fantasy       4469760
#       Adventure,Drama,Sci-Fi        1348184
#       Biography,Comedy,Drama         698385
#       Biography,Crime,Drama          933687
#       Biography,Documentary,Sport     56850
#       Biography,Drama,History       1120297
#       Biography,Drama,Music          665195
#       Comedy,Drama,Family            197987
#       Comedy,Drama,Romance           723495
#       Comedy,Drama,Thriller           73962
#       Comedy,Drama,War               186657
# ...

# %%
top3 = top.groupby(['tipo','titulo']).agg({'numVotes':'sum'})
top3
# Out:
#                                                          numVotes
# tipo  titulo
# movie 12 Angry Men                                         617607
#       American History X                                   973841
#       Back to the Future                                   965539
#       Casablanca                                           487781
#       City Lights                                          152730
#       City of God                                          659285
#       Fight Club                                          1725444
#       Forrest Gump                                        1662609
#       Gladiator                                           1246819
#       Goodfellas                                           933687
#       Inception                                           1892958
#       Interstellar                                        1348184
#       It's a Wonderful Life                                366750
# ...

# %%
top_pcts = top3.groupby(level = 0).apply(lambda x: 100 * x / float(x.sum()))
top_pcts.sort_values(by = ['numVotes'], ascending = False)
# Out:
#                                                          numVotes
# tipo  titulo
# movie The Shawshank Redemption                           4.527324
#       The Dark Knight                                    4.474619
#       Inception                                          3.968077
#       Fight Club                                         3.616929
#       Pulp Fiction                                       3.553445
#       Forrest Gump                                       3.485212
#       The Matrix                                         3.258266
#       The Lord of the Rings: The Fellowship of the Ring  3.246894
#       The Lord of the Rings: The Return of the King      3.214847
#       The Godfather                                      3.107086
#       The Lord of the Rings: The Two Towers              2.907908
#       Interstellar                                       2.826105
#       Se7en                                              2.782623
# ...

# %%
titles_sliced = titles_basic.iloc[:,[0,1,2,8]]  #minimizar a tabela para uma visualização curta, com
genres = titles_sliced['genres'].str.split(',', 1, expand = True )
#generos.head()
titles_sliced['gerero_1'] = genres[0]
titles_sliced['gerero_2'] = genres[1]
titles_sliced.drop(columns = ['genres'], inplace = True)
titles_sliced.head(5)
# Out:
# C:\Users\fic\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\fic\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       tconst titleType            primaryTitle     gerero_1        gerero_2
# 0  tt0000001     short              Carmencita  Documentary           Short
# ...

# %%
titles_sliced.columns = ['tconst', 'tipo', 'titulo', 'genero', 'sub.genero']
titles_sliced.head()
# Out:
#       tconst   tipo                  titulo       genero      sub.genero
# 0  tt0000001  short              Carmencita  Documentary           Short
# 1  tt0000002  short  Le clown et ses chiens    Animation           Short
# 2  tt0000003  short          Pauvre Pierrot    Animation  Comedy,Romance
# 3  tt0000004  short             Un bon bock    Animation           Short
# 4  tt0000005  short        Blacksmith Scene       Comedy           Short

# %%
titles_rating_merge = titles_rating.merge(titles_sliced, left_on = 'tconst', right_on = 'tconst') # fazendo a junção das tabelas com Merge, utilizando a coluna TCONST como chave primaria   
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html?highlight=merge#pandas.merge
titles_rating_merge.head()
# Out:
#       tconst  averageRating  numVotes   tipo                  titulo  \
# 0  tt0000001            5.6      1550  short              Carmencita
# 1  tt0000002            6.1       186  short  Le clown et ses chiens
# 2  tt0000003            6.5      1207  short          Pauvre Pierrot
# 3  tt0000004            6.2       113  short             Un bon bock
# 4  tt0000005            6.1      1934  short        Blacksmith Scene
#
#         genero      sub.genero
# 0  Documentary           Short
# 1    Animation           Short
# 2    Animation  Comedy,Romance
# 3    Animation           Short
# 4       Comedy           Short

# %%
titles_rating_merge.sort_values(by =['numVotes'], ascending=False).head(100)
# Out:
#            tconst  averageRating  numVotes      tipo  \
# 80579   tt0111161            9.3   2159745     movie
# 241008  tt0468569            9.0   2134602     movie
# 515622  tt1375666            8.8   1892958     movie
# 96689   tt0137523            8.8   1725444     movie
# 80363   tt0110912            8.9   1695159     movie
# 79501   tt0109830            8.8   1662609     movie
# 413358  tt0944947            9.4   1606096  tvSeries
# 94660   tt0133093            8.7   1554345     movie
# 88334   tt0120737            8.8   1548920     movie
# 111186  tt0167260            8.9   1533632     movie
# 44727   tt0068646            9.2   1482225     movie
# 509867  tt1345836            8.4   1421506     movie
# 111187  tt0167261            8.7   1387208     movie
# 378552  tt0816692            8.6   1348184     movie
# 83129   tt0114369            8.6   1327441     movie
# 403836  tt0903747            9.5   1280143  tvSeries
# 596786  tt1853728            8.4   1249336     movie
# ...

# %%
top = titles_rating_merge[(titles_rating_merge['numVotes'] > 50000)].sort_values(by =['averageRating'], ascending=False).head(50)
top
# Out:
#            tconst  averageRating  numVotes          tipo  \
# 652909  tt2301451           10.0    108546     tvEpisode
# 754712  tt3866850            9.9     85697     tvEpisode
# 652911  tt2301455            9.9     78605     tvEpisode
# 776333  tt4283094            9.9    126931     tvEpisode
# 637977  tt2178784            9.9     84994     tvEpisode
# 776332  tt4283088            9.9    182843     tvEpisode
# 852024  tt5775846            9.8     77872     tvEpisode
# 776326  tt4283028            9.7     62609     tvEpisode
# 120294  tt0185906            9.5    337036  tvMiniSeries
# 403836  tt0903747            9.5   1280143      tvSeries
# 923861  tt7366338            9.5    382356  tvMiniSeries
# 837163  tt5491994            9.5     81416  tvMiniSeries
# 852030  tt5775874            9.5     56493     tvEpisode
# 371428  tt0795176            9.4    154552  tvMiniSeries
# 413358  tt0944947            9.4   1606096      tvSeries
# ...

# %%
top_1 = top.groupby(['tipo','genero']).agg({'numVotes':'sum'})
top_1
# Out:
#                           numVotes
# tipo         genero
# movie        Action        2236419
#              Adventure     1533632
#              Biography     1120297
#              Crime         4209494
#              Drama         2777352
# tvEpisode    Action         734459
#              Crime          187151
# tvMiniSeries Action         337036
#              Biography       52985
#              Documentary    235968
#              Drama          452216
# tvSeries     Action        2213192
#              Adventure      615832
#              Animation      196475
#              Comedy        1195367
#              Crime         3518391
#              Documentary    100767
#              Drama          430476

# %%
top_pcts = top_1.groupby(level = 0).apply(lambda x: 100 * x / float(x.sum()))
top_pcts.sort_values(by = ['numVotes'], ascending = False)
# Out:
#                            numVotes
# tipo         genero
# tvEpisode    Action       79.693037
# tvSeries     Crime        42.541455
# tvMiniSeries Drama        41.941560
# movie        Crime        35.441822
# tvMiniSeries Action       31.258991
# tvSeries     Action       26.760075
# movie        Drama        23.383907
# tvMiniSeries Documentary  21.885263
# tvEpisode    Crime        20.306963
# movie        Action       18.829523
# tvSeries     Comedy       14.453383
# movie        Adventure    12.912410
#              Biography     9.432337
# tvSeries     Adventure     7.446128
#              Drama         5.204957
# tvMiniSeries Biography     4.914186
# tvSeries     Animation     2.375612
#              Documentary   1.218391

# %%
top_2 = top.groupby(['tipo','genero']).agg({'averageRating':'mean', 'numVotes':'sum'})
top_2
# Out:
#                           averageRating  numVotes
# tipo         genero
# movie        Action            9.000000   2236419
#              Adventure         8.900000   1533632
#              Biography         8.900000   1120297
#              Crime             9.033333   4209494
#              Drama             9.100000   2777352
# tvEpisode    Action            9.712500    734459
#              Crime             9.950000    187151
# tvMiniSeries Action            9.500000    337036
#              Biography         9.000000     52985
#              Documentary       9.450000    235968
#              Drama             9.200000    452216
# tvSeries     Action            9.057143   2213192
#              Adventure         9.133333    615832
#              Animation         9.000000    196475
#              Comedy            8.850000   1195367
#              Crime             9.114286   3518391
#              Documentary       9.300000    100767
# ...
